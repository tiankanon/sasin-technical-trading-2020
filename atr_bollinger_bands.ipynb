# %%
# import all dependencies
import datetime as dt
import yfinance as yf
from plotly.offline import plot
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
# time horizon set-up
start = dt.datetime.today() - dt.timedelta(365) # 1 year time-horizon
end = dt.datetime.today()

# %%
# getting data
stock = 'AAPL'
ohlcv = yf.download(stock, start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# atr function
def atr(df, n):
    df = df.copy()
    df['high-low'] = abs(df['High'] - df['Low'])
    df['high-pc'] = abs(df['High'] - df['Adj Close'].shift(1))
    df['low-pc'] = abs(df['Low'] - df['Adj Close'].shift(1))
    df['true-range'] = df[['high-low', 'high-pc', 'low-pc']].max(axis=1, skipna=False)
    df['atr'] = df['true-range'].rolling(n).mean()
    df.dropna(inplace=True)
    return df

# %%
# bollinger bands function
def bollinger_bands(df, std, n):
    df = df.copy()
    df['ma'] = df['Adj Close'].rolling(n).mean()
    df['bb-up'] = df['ma'] + (std * df['ma'].rolling(n).std())
    df['bb-down'] = df['ma'] - (std * df['ma'].rolling(n).std())
    df['bb-range'] = df['bb-up'] - df['bb-down']
    df.dropna(inplace=True)
    return df

# %%
# atr and bb
df_atr_bb = atr(ohlcv, 14)
df_atr_bb = bollinger_bands(df_atr_bb, 2, 20)

# %%
df_atr_bb
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-03-02   70.570000   75.360001   69.430000   74.702499   73.635773
# 2020-03-03   75.917503   76.000000   71.449997   72.330002   71.297157
# 2020-03-04   74.110001   75.849998   73.282501   75.684998   74.604240
# 2020-03-05   73.879997   74.887497   72.852501   73.230003   72.184303
# 2020-03-06   70.500000   72.705002   70.307503   72.257500   71.225685
# ...                ...         ...         ...         ...         ...
# 2020-12-07  122.309998  124.570000  122.250000  123.750000  123.750000
# 2020-12-08  124.370003  124.980003  123.089996  124.379997  124.379997
# 2020-12-09  124.529999  125.949997  121.000000  121.779999  121.779999
# 2020-12-10  120.500000  123.870003  120.150002  123.239998  123.239998
# 2020-12-11  122.430000  122.760002  120.550003  122.410004  122.410004
#
#                Volume  high-low   high-pc    low-pc  true-range       atr  \
# Date
# 2020-03-02  341397200  5.930000  7.995872  2.065872    7.995872  3.213750
# 2020-03-03  319475600  4.550003  2.364227  2.185776    4.550003  3.414793
# 2020-03-04  219178400  2.567497  4.552841  1.985344    4.552841  3.522604
# 2020-03-05  187572800  2.034996  0.283257  1.751740    2.034996  3.602027
# 2020-03-06  226176800  2.397499  0.520699  1.876801    2.397499  3.670616
# ...               ...       ...       ...       ...         ...       ...
# 2020-12-07   86712000  2.320000  2.320000  0.000000    2.320000  2.430001
# 2020-12-08   82225500  1.890007  1.230003  0.660004    1.890007  2.442859
# 2020-12-09  115089200  4.949997  1.570000  3.379997    4.949997  2.666430
# 2020-12-10   81312200  3.720001  2.090004  1.629997    3.720001  2.771430
# 2020-12-11   86860000  2.209999  0.479996  2.689995    2.689995  2.857858
#
#                     ma       bb-up     bb-down  bb-range
# Date
# 2020-03-02   76.515720   77.898298   75.133141  2.765156
# 2020-03-03   76.286427   77.794002   74.778851  3.015152
# 2020-03-04   76.097229   77.779142   74.415316  3.363826
# 2020-03-05   75.755074   77.671028   73.839119  3.831910
# 2020-03-06   75.318769   77.517879   73.119659  4.398220
# ...                ...         ...         ...       ...
# 2020-12-07  118.969000  121.371828  116.566172  4.805656
# 2020-12-08  119.372000  122.071394  116.672606  5.398788
# 2020-12-09  119.662500  122.615506  116.709493  5.906014
# 2020-12-10  119.850000  123.004091  116.695909  6.308182
# 2020-12-11  120.010000  123.309539  116.710461  6.599078
#
# [200 rows x 15 columns]

# %%
# create figure
fig = make_subplots(specs=[[{"secondary_y": True}]])
fig.add_trace(go.Scatter(x=df_atr_bb.index, y=df_atr_bb['Adj Close'], name='price'))
fig.add_trace(go.Scatter(x=df_atr_bb.index, y=df_atr_bb['ma'], name='ma'))
fig.add_trace(go.Scatter(x=df_atr_bb.index, y=df_atr_bb['bb-up'], name='bb-up'))
fig.add_trace(go.Scatter(x=df_atr_bb.index, y=df_atr_bb['bb-down'], name='bb-down'))
fig.add_trace(go.Scatter(x=df_atr_bb.index, y=df_atr_bb['atr'], name='atr'), secondary_y=True)

# format figure
fig.update_layout(title_text=f'ATR & Bollinger Bands of {stock}')
fig.update_xaxes(title_text='Date')
fig.update_yaxes(title_text='Price')
fig.update_yaxes(title_text='ATR', secondary_y=True)
# Out:
# <div>                            <div id="6aa182ec-2b69-44a4-80b5-b26360bbbba2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6aa182ec-2b69-44a4-80b5-b26360bbbba2")) {                    Plotly.newPlot(                        "6aa182ec-2b69-44a4-80b5-b26360bbbba2",                        [{"name": "price", "type": "scatter", "x": ["2020-03-02T00:00:00", "2020-03-03T00:00:00", "2020-03-04T00:00:00", "2020-03-05T00:00:00", "2020-03-06T00:00:00", "2020-03-09T00:00:00", "2020-03-10T00:00:00", "2020-03-11T00:00:00", "2020-03-12T00:00:00", "2020-03-13T00:00:00", "2020-03-16T00:00:00", "2020-03-17T00:00:00", "2020-03-18T00:00:00", "2020-03-19T00:00:00", "2020-03-20T00:00:00", "2020-03-23T00:00:00", "2020-03-24T00:00:00", "2020-03-25T00:00:00", "2020-03-26T00:00:00", "2020-03-27T00:00:00", "2020-03-30T00:00:00", "2020-03-31T00:00:00", "2020-04-01T00:00:00", "2020-04-02T00:00:00", "2020-04-03T00:00:00", "2020-04-06T00:00:00", "2020-04-07T00:00:00", "2020-04-08T00:00:00", "2020-04-09T00:00:00", "2020-04-13T00:00:00", "2020-04-14T00:00:00", "2020-04-15T00:00:00", "2020-04-16T00:00:00", "2020-04-17T00:00:00", "2020-04-20T00:00:00", "2020-04-21T00:00:00", "2020-04-22T00:00:00", "2020-04-23T00:00:00", "2020-04-24T00:00:00", "2020-04-27T00:00:00", "2020-04-28T00:00:00", "2020-04-29T00:00:00", "2020-04-30T00:00:00", "2020-05-01T00:00:00", "2020-05-04T00:00:00", "2020-05-05T00:00:00", "2020-05-06T00:00:00", "2020-05-07T00:00:00", "2020-05-08T00:00:00", "2020-05-11T00:00:00", "2020-05-12T00:00:00", "2020-05-13T00:00:00", "2020-05-14T00:00:00", "2020-05-15T00:00:00", "2020-05-18T00:00:00", "2020-05-19T00:00:00", "2020-05-20T00:00:00", "2020-05-21T00:00:00", "2020-05-22T00:00:00", "2020-05-26T00:00:00", "2020-05-27T00:00:00", "2020-05-28T00:00:00", "2020-05-29T00:00:00", "2020-06-01T00:00:00", "2020-06-02T00:00:00", "2020-06-03T00:00:00", "2020-06-04T00:00:00", "2020-06-05T00:00:00", "2020-06-08T00:00:00", "2020-06-09T00:00:00", "2020-06-10T00:00:00", "2020-06-11T00:00:00", "2020-06-12T00:00:00", "2020-06-15T00:00:00", "2020-06-16T00:00:00", "2020-06-17T00:00:00", "2020-06-18T00:00:00", "2020-06-19T00:00:00", "2020-06-22T00:00:00", "2020-06-23T00:00:00", "2020-06-24T00:00:00", "2020-06-25T00:00:00", "2020-06-26T00:00:00", "2020-06-29T00:00:00", "2020-06-30T00:00:00", "2020-07-01T00:00:00", "2020-07-02T00:00:00", "2020-07-06T00:00:00", "2020-07-07T00:00:00", "2020-07-08T00:00:00", "2020-07-09T00:00:00", "2020-07-10T00:00:00", "2020-07-13T00:00:00", "2020-07-14T00:00:00", "2020-07-15T00:00:00", "2020-07-16T00:00:00", "2020-07-17T00:00:00", "2020-07-20T00:00:00", "2020-07-21T00:00:00", "2020-07-22T00:00:00", "2020-07-23T00:00:00", "2020-07-24T00:00:00", "2020-07-27T00:00:00", "2020-07-28T00:00:00", "2020-07-29T00:00:00", "2020-07-30T00:00:00", "2020-07-31T00:00:00", "2020-08-03T00:00:00", "2020-08-04T00:00:00", "2020-08-05T00:00:00", "2020-08-06T00:00:00", "2020-08-07T00:00:00", "2020-08-10T00:00:00", "2020-08-11T00:00:00", "2020-08-12T00:00:00", "2020-08-13T00:00:00", "2020-08-14T00:00:00", "2020-08-17T00:00:00", "2020-08-18T00:00:00", "2020-08-19T00:00:00", "2020-08-20T00:00:00", "2020-08-21T00:00:00", "2020-08-24T00:00:00", "2020-08-25T00:00:00", "2020-08-26T00:00:00", "2020-08-27T00:00:00", "2020-08-28T00:00:00", "2020-08-31T00:00:00", "2020-09-01T00:00:00", "2020-09-02T00:00:00", "2020-09-03T00:00:00", "2020-09-04T00:00:00", "2020-09-08T00:00:00", "2020-09-09T00:00:00", "2020-09-10T00:00:00", "2020-09-11T00:00:00", "2020-09-14T00:00:00", "2020-09-15T00:00:00", "2020-09-16T00:00:00", "2020-09-17T00:00:00", "2020-09-18T00:00:00", "2020-09-21T00:00:00", "2020-09-22T00:00:00", "2020-09-23T00:00:00", "2020-09-24T00:00:00", "2020-09-25T00:00:00", "2020-09-28T00:00:00", "2020-09-29T00:00:00", "2020-09-30T00:00:00", ...
